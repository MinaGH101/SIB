# %%
import roboflow

# %%
roboflow.login()
# Out:
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 roboflow.login()
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/roboflow/__init__.py:93, in login(workspace, force)
#      91 r_login = r_login.json()
#      92 if r_login is None:
# ---> 93     raise ValueError("Invalid API key. Please check your API key and try again.")
#      95 # make config directory if it doesn't exist
#      96 if not os.path.exists(os.path.dirname(conf_location)):
#
# ValueError: Invalid API key. Please check your API key and try again.

# %%
# !export ROBOFLOW_API_KEY="AKfKTo16PhwaLa7DTtgO"

# %%
from inference import InferencePipeline
from inference.core.interfaces.stream.sinks import render_boxes

pipeline = InferencePipeline.init(
    model_id="model_id/version",
    video_reference="video.mp4", # Replace with the path to your video
    on_prediction=render_boxes, # Function to run after each prediction
)
pipeline.start()
pipeline.join()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/inference/core/roboflow_api.py:141, in wrap_roboflow_api_errors.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     140 try:
# --> 141     return function(*args, **kwargs)
#     142 except RetryRequestError as error:
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/inference/core/roboflow_api.py:448, in get_roboflow_instant_model_data(api_key, model_id, cache_prefix, countinference, service_secret)
#     444 api_url = _add_params_to_url(
#     445     url=f"{api_base_url}/getWeights",
#     446     params=params,
#     447 )
# --> 448 api_data = _get_from_url(url=api_url)
#     449 cache.set(
#     450     api_data_cache_key,
#     451     api_data,
#     452     expire=10,
#     453 )
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/backoff/_sync.py:105, in retry_exception.<locals>.retry(*args, **kwargs)
#     104 try:
# --> 105     ret = target(*args, **kwargs)
#     106 except exception as e:
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/inference/core/roboflow_api.py:915, in _get_from_url(url, json_response)
#     914         raise RetryRequestError(message=str(error), inner_error=error) from error
# --> 915     raise error
#     917 if MD5_VERIFICATION_ENABLED:
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/inference/core/roboflow_api.py:911, in _get_from_url(url, json_response)
#     910 try:
# --> 911     api_key_safe_raise_for_status(response=response)
#     912 except Exception as error:
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/inference/core/utils/requests.py:16, in api_key_safe_raise_for_status(response)
#      15 response.url = API_KEY_PATTERN.sub(deduct_api_key, response.url)
# ---> 16 response.raise_for_status()
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.roboflow.com/getWeights?model=model_id%2Fversion
#
# The above exception was the direct cause of the following exception:
#
# RoboflowAPIForbiddenError                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 from inference import InferencePipeline
#       2 from inference.core.interfaces.stream.sinks import render_boxes
# ----> 4 pipeline = InferencePipeline.init(
#       5     model_id="model_id/version",
#       6     video_reference="video.mp4", # Replace with the path to your video
#       7     on_prediction=render_boxes, # Function to run after each prediction
#       8 )
#       9 pipeline.start()
#      10 pipeline.join()
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/inference/core/interfaces/stream/inference_pipeline.py:254, in InferencePipeline.init(cls, video_reference, model_id, on_prediction, api_key, max_fps, watchdog, status_update_handlers, source_buffer_filling_strategy, source_buffer_consumption_strategy, class_agnostic_nms, confidence, iou_threshold, max_candidates, max_detections, mask_decode_mode, tradeoff_factor, active_learning_enabled, video_source_properties, active_learning_target_dataset, batch_collection_timeout, sink_mode, predictions_queue_size, decoding_buffer_size)
#     244     api_key = API_KEY
#     245 inference_config = ModelConfig.init(
#     246     class_agnostic_nms=class_agnostic_nms,
#     247     confidence=confidence,
#    (...)
#     252     tradeoff_factor=tradeoff_factor,
#     253 )
# --> 254 model = get_model(model_id=model_id, api_key=api_key)
#     255 on_video_frame = partial(
#     256     default_process_frame, model=model, inference_config=inference_config
#     257 )
#     258 active_learning_middleware = NullActiveLearningMiddleware()
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/inference/models/utils.py:693, in get_model(model_id, api_key, **kwargs)
#     692 def get_model(model_id, api_key=API_KEY, **kwargs) -> Model:
# --> 693     task, model = get_model_type(model_id, api_key=api_key)
#     694     return ROBOFLOW_MODEL_TYPES[(task, model)](model_id, api_key=api_key, **kwargs)
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/inference/core/registries/roboflow.py:222, in get_model_type(model_id, api_key, countinference, service_secret)
#     220     project_task_type = api_data.get("type", "object-detection")
#     221 else:
# --> 222     api_data = get_roboflow_instant_model_data(
#     223         api_key=api_key,
#     224         model_id=model_id,
#     225         countinference=countinference,
#     226         service_secret=service_secret,
#     227     )
#     228     project_task_type = api_data.get("taskType", "object-detection")
#     229 if api_data is None:
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/inference/core/roboflow_api.py:160, in wrap_roboflow_api_errors.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     158     error_handler = user_handler_override.get(status_code, default_handler)
#     159     if error_handler is not None:
# --> 160         error_handler(error)
#     161     raise RoboflowAPIUnsuccessfulRequestError(
#     162         f"Unsuccessful request to Roboflow API with response code: {status_code}"
#     163     ) from error
#     164 except requests.exceptions.InvalidJSONError as error:
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/inference/core/roboflow_api.py:115, in <lambda>(e)
#     102 def raise_from_lambda(
#     103     inner_error: Exception, exception_type: Type[Exception], message: str
#     104 ) -> None:
#     105     raise exception_type(message) from inner_error
#     108 DEFAULT_ERROR_HANDLERS = {
#     109     401: lambda e: raise_from_lambda(
#     110         e,
#     111         RoboflowAPINotAuthorizedError,
#     112         "Unauthorized access to roboflow API - check API key. Visit "
#     113         "https://docs.roboflow.com/api-reference/authentication#retrieve-an-api-key to learn how to retrieve one.",
#     114     ),
# --> 115     403: lambda e: raise_from_lambda(
#     116         e,
#     117         RoboflowAPIForbiddenError,
#     118         "Unauthorized access to roboflow API - check API key regarding correctness and required scopes. Visit "
#     119         "https://docs.roboflow.com/api-reference/authentication#retrieve-an-api-key to learn how to retrieve one.",
#     120     ),
#     121     404: lambda e: raise_from_lambda(
#     122         e, RoboflowAPINotNotFoundError, NOT_FOUND_ERROR_MESSAGE
#     123     ),
#     124     423: lambda e: raise_from_lambda(
#     125         e,
#     126         RoboflowAPIUsagePausedError,
#     127         "Roboflow API usage is paused. Please contact your workspace administrator to re-enable api keys.",
#     128     ),
#     129 }
#     132 def wrap_roboflow_api_errors(
#     133     http_errors_handlers: Optional[
#     134         Dict[int, Callable[[Union[requests.exceptions.HTTPError]], None]]
#     135     ] = None,
#     136 ) -> callable:
#     137     def decorator(function: callable) -> callable:
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/inference/core/roboflow_api.py:105, in raise_from_lambda(inner_error, exception_type, message)
#     102 def raise_from_lambda(
#     103     inner_error: Exception, exception_type: Type[Exception], message: str
#     104 ) -> None:
# --> 105     raise exception_type(message) from inner_error
#
# RoboflowAPIForbiddenError: Unauthorized access to roboflow API - check API key regarding correctness and required scopes. Visit https://docs.roboflow.com/api-reference/authentication#retrieve-an-api-key to learn how to retrieve one.
